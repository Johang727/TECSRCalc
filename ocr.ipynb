# %%
import pytesseract

from PIL import Image

# %%
img = Image.open(r"data/validation_processed/testing/1_tec_results/bw_Discord_9l84CUi6WD.png")

# %%
print(pytesseract.image_to_string(img))
# Out:
# 0,86

# %%
pdf = pytesseract.image_to_pdf_or_hocr(r"data/validation_processed/testing/1_tec_results/bw_Discord_9l84CUi6WD.png", extension='pdf')
with open('test.pdf', 'w+b') as f:
    f.write(pdf) # pdf type is bytes by default
